# %%
import pylab as plt
import sys
import pandas as pd
import numpy as np
import math as m

print(sys.version)
# Out:
# 3.8.6 (tags/v3.8.6:db45529, Sep 23 2020, 15:52:53) [MSC v.1927 64 bit (AMD64)]

# %%
filein=open("Multigrid_gamma1.dat", "r")
xin=[]
yin=[]
y1in=[]


for line in filein:
    data=line.split()
    xin.append(float(data[0]))
    yin.append(float(data[1]))
    y1in.append(float(data[2]))

filein.close()

# %%
plt.scatter(xin,y1in, label=r"$\gamma=1$")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$C(\tau)$')
plt.legend()
plt.savefig('magnitization_square_autocorrelation_gamma1')

# %%
plt.scatter(xin,yin, label=r"$\gamma=1$")
plt.xlabel(r'i')
plt.ylabel(r'$\phi_i$')
plt.legend()
plt.savefig('magnitization_square_multigrid_gamma1')
