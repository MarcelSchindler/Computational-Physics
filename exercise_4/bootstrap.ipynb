# %%
import pylab as plt
import sys
import pandas as pd
import numpy as np
import math as m

print(sys.version)
# Out:
# 3.8.6 (tags/v3.8.6:db45529, Sep 23 2020, 15:52:53) [MSC v.1927 64 bit (AMD64)]

# %%
filein=open("bootstrap.dat", "r")
xin=[]
yin=[]


for line in filein:
    data=line.split()
    xin.append(float(data[0])*1000)
    yin.append(float(data[1])*1000)    
filein.close()

# %%
plt.scatter(xin,yin, label=r"Bootstrap")
plt.xlabel(r'$N_{bs}$')
plt.ylabel(r'$\delta m/\cdot 10^3$')
plt.legend()
plt.savefig('bootstrap')
